# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 30.99 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# !pip3 install -r /content/OIDv4_ToolKit/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 19.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes Boy Girl --type_csv test --limit 50
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Boy.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...145%, 0 MB, 36451 KB/s, 0 seconds passed
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes Boy Girl --type_csv train --limit 50
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Boy.
#    [ERROR] | Missing the train-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...100%, 1138 MB, 35491 KB/s, 32 seconds passed
# ...

# %%
# !zip -r /content/file.zip /content/OID/Dataset
# Out:
#   adding: content/OID/Dataset/ (stored 0%)
#   adding: content/OID/Dataset/test/ (stored 0%)
#   adding: content/OID/Dataset/test/Girl/ (stored 0%)
#   adding: content/OID/Dataset/test/Girl/79fcbc5d72c5cd5a.jpg (deflated 1%)
#   adding: content/OID/Dataset/test/Girl/8dbc67a851d8d076.jpg (deflated 3%)
#   adding: content/OID/Dataset/test/Girl/9915966b1b5ada24.jpg (deflated 0%)
#   adding: content/OID/Dataset/test/Girl/71a80fa87eb3e89d.jpg (deflated 0%)
#   adding: content/OID/Dataset/test/Girl/ae22df4e4466c1e8.jpg (deflated 1%)
#   adding: content/OID/Dataset/test/Girl/9126f6df177ea1dc.jpg (deflated 1%)
#   adding: content/OID/Dataset/test/Girl/8892d440d3b917b2.jpg (deflated 0%)
#   adding: content/OID/Dataset/test/Girl/348fba599faf3ffe.jpg (deflated 3%)
#   adding: content/OID/Dataset/test/Girl/685c59468727bff2.jpg (deflated 14%)
#   adding: content/OID/Dataset/test/Girl/d9414a24b8ae0c4c.jpg (deflated 0%)
#   adding: content/OID/Dataset/test/Girl/78e8079bd982f3f7.jpg (deflated 0%)
# ...
